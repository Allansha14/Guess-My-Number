# %% [markdown]
# # Number guessing name

# %%
print("""Instructions
Enter the range of numbers you want the target number to be between, and press New Target
Enter your guess
See if your guess is too high or too low
Change your guess
The app will tell you when you are right, and how many guesses you had""")
# Out:
# Instructions
# Enter the range of numbers you want the target number to be between, and press New Target
# Enter your guess
# See if your guess is too high or too low
# Change your guess
# The app will tell you when you are right, and how many guesses you had

# %% [markdown]
# ## level -1 . print if the user guessed number is right or not .

# %%
#seceret_number=53

# %%
#user_guess = input(" please enter your guess")
# Out:
#  please enter your guess 25

# %%
#if seceret_number == user_guess:
    print("congrulation , Your guess is correct")
else:
    print("sorry , your guess is not correct")
# Out:
# sorry , your guess is not correct

# %%
""" seceret_number=53
user_guess = int(input("please enter your guess"))
if seceret_number == user_guess:
    print("congrulation , Your guess is correct")
else:
    print("sorry , your guess is not correct")"""
# Out:
# ' seceret_number=53\nuser_guess = int(input("please enter your guess"))\nif seceret_number == user_guess:\n    print("congrulation , Your guess is correct")\nelse:\n    print("sorry , your guess is not correct")'

# %% [markdown]
# ## level -2 . print if the user guessed number is right or not . But with max of 7 trails

# %% [markdown]
# #### Using for loop End interation number is defined

# %%
seceret_number=53
for i in range (0,7):     # start value is 0   end value is 7 beacuse we need a maximum trail of 7
    user_guess = int(input("please enter your guess"))
    if seceret_number == user_guess:
         print("congrulation , Your guess is correct")
         break
    else:
        print("sorry , your guess is not correct")
# Out:
# please enter your guess 10
# sorry , your guess is not correct
# please enter your guess 53
# congrulation , Your guess is correct

# %% [markdown]
# ####  Using While loop End interation is not defined

# %%
seceret_number=53
while True :
    user_guess = int(input("please enter your guess"))
    if seceret_number == user_guess:
        print("congrulation , Your guess is correct")
        break
    else:
        print("sorry , your guess is not correct")
# Out:
# please enter your guess 20
# sorry , your guess is not correct
# please enter your guess 230
# sorry , your guess is not correct
# please enter your guess 50
# sorry , your guess is not correct
# please enter your guess 53
# congrulation , Your guess is correct

# %% [markdown]
# ## level 3 : give multiple condition
#
# 1. user shoukd enter the number between 1-100. if it's entering wrong , the program should say ,"invalid number"
#
# 2. If the user guessed number>seceret number , then program should say " your number is greater than secret number "
#
# 3.  If the user guessed number<seceret number , then program should say " your number is less than secret number "

# %%
print(' Welcome to Number Guessing Game !!! ')  
print (' Guess the number between 1-100 ')

seceret_number=53

for i in range (1,8):
    user_input = int(input("please enter your guess"))
    if user_input < 1 or user_input > 100 :
        print('Invalid number ! please enter the number between 1 -100')
    elif user_input > seceret_number :
        print('Your number is greater')
    elif user_input < seceret_number :
        print('Your number is lesser')
    else :
        print ("Well Done! you successfully find the number")
        print(f"Well Done! It took you {i} attempts to guess this secret number ")
        break
# Out:
#  Welcome to Number Guessing Game !!!
#  Guess the number between 1-100
# please enter your guess 5
# Your number is lesser
# please enter your guess 55
# Your number is greater
# please enter your guess 13
# Your number is lesser
# please enter your guess 53
# Well Done! you successfully find the number
# Well Done! It took you 4 attempts to guess this secret number

# %% [markdown]
# ## Level 4 : setting Multiple Condition

# %%
print(' Welcome to Number Guessing Game !!! ')  
print (' Guess the number between 1-100 ')

seceret_number=53

for i in range (1,8):
    user_input = int(input("please enter your guess"))
    if user_input < 1 or user_input > 100 :
        print('Invalid number ! please enter the number between 1 -100')
    elif user_input > seceret_number :
        print('Your number is greater')
    elif user_input < seceret_number :
        print('Your number is lesser')
    else :
        print ("Well Done! you successfully find the number")
        
        break

if  user_input == seceret_number:
    print(f"Well Done! It took you {i} attempts to guess this secret number ")
else:
    print('sorry your attempt is completed ')
# Out:
#  Welcome to Number Guessing Game !!!
#  Guess the number between 1-100
# please enter your guess 53
# Well Done! you successfully find the number
# Well Done! It took you 1 attempts to guess this secret number

# %% [markdown]
# ## Level 5 : Secrect number shouldn't be fix it was random

# %%
import random

# %%
seceret_number=random.randint(1,100)

# %%
import random

print(' Welcome to Number Guessing Game !!! ')  
print (' Guess the number between 1-100 ')

seceret_number=random.randint(1,100)

for i in range (1,8):
    user_input = int(input("please enter your guess"))
    if user_input < 1 or user_input > 100 :
        print('Invalid number ! please enter the number between 1 -100')
    elif user_input > seceret_number :
        print('Your number is greater')
    elif user_input < seceret_number :
        print('Your number is lesser')
    else :
        print ("Well Done! you successfully find the number")
        
        break

if  user_input == seceret_number:
    print(f"Well Done! It took you {i} attempts to guess this secret number ")
else:
    print('sorry your attempt is completed ')
# Out:
#  Welcome to Number Guessing Game !!!
#  Guess the number between 1-100
# please enter your guess 10
# Your number is lesser
# please enter your guess 50
# Your number is lesser
# please enter your guess 80
# Your number is greater
# please enter your guess 70
# Your number is lesser
# please enter your guess 75
# Well Done! you successfully find the number
# Well Done! It took you 5 attempts to guess this secret number

# %% [markdown]
# #### Take out the limits for try

# %%
import random

print(' Welcome to Number Guessing Game !!! ')  
print (' Guess the number between 1-100 ')

seceret_number=random.randint(1,100)

while True:
    user_input = int(input("please enter your guess"))
    if user_input < 1 or user_input > 100 :
        print('Invalid number ! please enter the number between 1 -100')
    elif user_input > seceret_number :
        print('Your number is greater')
    elif user_input < seceret_number :
        print('Your number is lesser')
    else :
        print ("Well Done! you successfully find the number")
        
        break
# Out:
#  Welcome to Number Guessing Game !!!
#  Guess the number between 1-100
# please enter your guess 55
# Your number is lesser
# please enter your guess 20
# Your number is lesser
# please enter your guess 10
# Your number is lesser
# please enter your guess 90
# Your number is greater
# please enter your guess 70
# Your number is lesser
# please enter your guess 80
# Your number is greater
# please enter your guess 75
# Your number is greater
# please enter your guess 73
# Your number is greater
# please enter your guess 72
# Your number is greater
# please enter your guess 60
# Your number is lesser
# please enter your guess 65
# Your number is lesser
# please enter your guess 67
# Your number is lesser
# please enter your guess 71
# Well Done! you successfully find the number
# Well Done! It took you 5 attempts to guess this secret number

# %% [markdown]
# ## Level 6 Exception handling

# %%
import random

print(' Welcome to Number Guessing Game !!! ')  
print (' Guess the number between 1-100 ')

seceret_number=random.randint(1,100)

for i in range (1,8):
    try:
        user_input = int(input("please enter your guess"))
        if user_input < 1 or user_input > 100 :
            print('Invalid number ! please enter the number between 1 -100')
        elif user_input > seceret_number :
            print('Your number is greater')
        elif user_input < seceret_number :
            print('Your number is lesser')
        else :
            print ("Well Done! you successfully find the number")
            
            break
    except ValueError:
        print("Invalid character !!!   please enter the number between 1 -100 ")

if  user_input == seceret_number:
    print(f"Well Done! It took you {i} attempts to guess this secret number ")
else:
    print('sorry your attempt is completed ')
# Out:
#  Welcome to Number Guessing Game !!!
#  Guess the number between 1-100
# please enter your guess sss
# Invalid character !!!   please enter the number between 1 -100
# please enter your guess ss
# Invalid character !!!   please enter the number between 1 -100
# please enter your guess s
# Invalid character !!!   please enter the number between 1 -100
# please enter your guess s
# Invalid character !!!   please enter the number between 1 -100
# please enter your guess s
# Invalid character !!!   please enter the number between 1 -100
# please enter your guess s
# Invalid character !!!   please enter the number between 1 -100
# please enter your guess s
# Invalid character !!!   please enter the number between 1 -100
# sorry your attempt is completed

# %% [markdown]
# ##  Level 7- Take this program to run as a function when it is called
#
# Step 1: Define a Function
#
# Step 2 : call the function

# %%
def number_guessing_game():
    import random

print(' Welcome to Number Guessing Game !!! ')  
print (' Guess the number between 1-100 ')

seceret_number=random.randint(1,100)

for i in range (1,8):
    try:
        user_input = int(input("please enter your guess"))
        if user_input < 1 or user_input > 100 :
            print('Invalid number ! please enter the number between 1 -100')
        elif user_input > seceret_number :
            print('Your number is greater')
        elif user_input < seceret_number :
            print('Your number is lesser')
        else :
            print ("Well Done! you successfully find the number")
            
            break
    except ValueError:
        print("Invalid character !!!   please enter the number between 1 -100 ")

if  user_input == seceret_number:
    print(f"Well Done! It took you {i} attempts to guess this secret number ")
else:
    print('sorry your attempt is completed ')
# Out:
#  Welcome to Number Guessing Game !!!
#  Guess the number between 1-100
# please enter your guess s
# Invalid character !!!   please enter the number between 1 -100
# please enter your guess s
# Invalid character !!!   please enter the number between 1 -100
# please enter your guess s
# Invalid character !!!   please enter the number between 1 -100
# please enter your guess s
# Invalid character !!!   please enter the number between 1 -100
# please enter your guess s
# Invalid character !!!   please enter the number between 1 -100
# please enter your guess s
# Invalid character !!!   please enter the number between 1 -100
# please enter your guess s
# Invalid character !!!   please enter the number between 1 -100
# sorry your attempt is completed

# %%
number_guessing_game()
